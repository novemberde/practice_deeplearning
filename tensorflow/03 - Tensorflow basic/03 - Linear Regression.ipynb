# %%
# X와 Y의 상관관계를 분석하는 기초적인 선형 회귀 모델을 만들고 실행
import tensorflow as tf

x_data = [1,2,3]
y_data = [1,2,3]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# name: 나중에 텐서보드등으로 값의 변화를 추적하거나 살펴보기 쉽게 하기 위해 이름을 붙여준다
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")

print(X)
print(Y)
# Out:
# Tensor("X_1:0", dtype=float32)
# Tensor("Y_1:0", dtype=float32)

# %%
# X와 Y의 상관 관계를 분석하기 위한 가설 수식을 작성한다.
# y = W * x + b
# W와 X 가 행렬이 아니므로 tf.matmul이 아니라 기본 곱셈 기호를 사용
hypothesis = W * X + b

# 손실 함수를 작성한다
# mean(h - Y)^2 : 예측값과 실제값의 거리를 비용(손실) 함수로 정함
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# 텐서플로우에 기본적으로 포함되어 있는 함수를 이용해 경사 하강법 최적화를 수행
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
# 비용을 최소화 하는 것이 최종 목표
train_op = optimizer.minimize(cost)

# %%
# 세션을 생성하고 초기화합니다.
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # 최적화를 100번 수행합니다.
    for step in range(100):
        # sess.run 을 통해 train_op 와 cost 그래프를 계산합니다.
        # 이 때, 가설 수식에 넣어야 할 실제값을 feed_dict 을 통해 전달합니다.
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})

        print(step, cost_val, sess.run(W), sess.run(b))

    # 최적화가 완료된 모델에 테스트 값을 넣고 결과가 잘 나오는지 확인해봅니다.
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# (0, 19.175337, array([ 1.22900653], dtype=float32), array([-0.0159232], dtype=float32))
# (1, 0.23040605, array([ 1.02163637], dtype=float32), array([-0.10434116], dtype=float32))
# (2, 0.0040414459, array([ 1.04317892], dtype=float32), array([-0.09212746], dtype=float32))
# (3, 0.0012762283, array([ 1.0397296], dtype=float32), array([-0.09097353], dtype=float32))
# (4, 0.0011848708, array([ 1.03903806], dtype=float32), array([-0.08867066], dtype=float32))
# (5, 0.0011282208, array([ 1.0380708], dtype=float32), array([-0.08655174], dtype=float32))
# (6, 0.0010746316, array([ 1.03715873], dtype=float32), array([-0.08446972], dtype=float32))
# (7, 0.0010235814, array([ 1.03626513], dtype=float32), array([-0.08243927], dtype=float32))
# (8, 0.00097496249, array([ 1.03539336], dtype=float32), array([-0.08045747], dtype=float32))
# (9, 0.00092865172, array([ 1.03454256], dtype=float32), array([-0.07852333], dtype=float32))
# (10, 0.00088453759, array([ 1.03371215], dtype=float32), array([-0.07663569], dtype=float32))
# (11, 0.00084252487, array([ 1.03290176], dtype=float32), array([-0.07479341], dtype=float32))
# (12, 0.00080250314, array([ 1.03211081], dtype=float32), array([-0.07299544], dtype=float32))
# (13, 0.00076438423, array([ 1.03133881], dtype=float32), array([-0.07124069], dtype=float32))
# (14, 0.00072807493, array([ 1.03058553], dtype=float32), array([-0.06952809], dtype=float32))
# (15, 0.00069348997, array([ 1.02985024], dtype=float32), array([-0.06785668], dtype=float32))
# (16, 0.0006605463, array([ 1.02913272], dtype=float32), array([-0.06622543], dtype=float32))
# (17, 0.000629168, array([ 1.02843237], dtype=float32), array([-0.06463342], dtype=float32))
# (18, 0.00059928617, array([ 1.02774882], dtype=float32), array([-0.06307969], dtype=float32))
# (19, 0.00057082082, array([ 1.02708173], dtype=float32), array([-0.06156329], dtype=float32))
# (20, 0.00054370501, array([ 1.02643073], dtype=float32), array([-0.06008332], dtype=float32))
# (21, 0.00051787816, array([ 1.02579534], dtype=float32), array([-0.05863895], dtype=float32))
# (22, 0.00049327454, array([ 1.02517533], dtype=float32), array([-0.05722929], dtype=float32))
# (23, 0.00046984697, array([ 1.02457011], dtype=float32), array([-0.05585356], dtype=float32))
# (24, 0.00044752992, array([ 1.02397943], dtype=float32), array([-0.0545109], dtype=float32))
# (25, 0.00042627208, array([ 1.02340293], dtype=float32), array([-0.05320049], dtype=float32))
# (26, 0.00040602265, array([ 1.02284038], dtype=float32), array([-0.05192157], dtype=float32))
# (27, 0.00038673435, array([ 1.0222913], dtype=float32), array([-0.05067339], dtype=float32))
# (28, 0.00036836546, array([ 1.02175546], dtype=float32), array([-0.04945524], dtype=float32))
# (29, 0.000350869, array([ 1.02123249], dtype=float32), array([-0.04826638], dtype=float32))
# (30, 0.00033420007, array([ 1.02072203], dtype=float32), array([-0.04710609], dtype=float32))
# (31, 0.00031832847, array([ 1.02022386], dtype=float32), array([-0.0459737], dtype=float32))
# (32, 0.00030320551, array([ 1.01973772], dtype=float32), array([-0.0448685], dtype=float32))
# (33, 0.00028880316, array([ 1.01926327], dtype=float32), array([-0.04378989], dtype=float32))
# (34, 0.00027508495, array([ 1.01880014], dtype=float32), array([-0.04273723], dtype=float32))
# (35, 0.00026201751, array([ 1.01834822], dtype=float32), array([-0.04170983], dtype=float32))
# (36, 0.00024957155, array([ 1.01790714], dtype=float32), array([-0.04070714], dtype=float32))
# (37, 0.00023771782, array([ 1.01747668], dtype=float32), array([-0.03972857], dtype=float32))
# (38, 0.00022642595, array([ 1.01705647], dtype=float32), array([-0.03877354], dtype=float32))
# (39, 0.0002156699, array([ 1.0166465], dtype=float32), array([-0.03784142], dtype=float32))
# (40, 0.00020542757, array([ 1.01624632], dtype=float32), array([-0.03693175], dtype=float32))
# (41, 0.00019566766, array([ 1.01585579], dtype=float32), array([-0.03604392], dtype=float32))
# (42, 0.0001863737, array([ 1.01547456], dtype=float32), array([-0.03517746], dtype=float32))
# (43, 0.00017752027, array([ 1.01510262], dtype=float32), array([-0.03433179], dtype=float32))
# (44, 0.00016908791, array([ 1.01473951], dtype=float32), array([-0.03350648], dtype=float32))
# (45, 0.00016105625, array([ 1.01438522], dtype=float32), array([-0.03270099], dtype=float32))
# (46, 0.00015340581, array([ 1.0140394], dtype=float32), array([-0.03191488], dtype=float32))
# (47, 0.00014611737, array([ 1.01370192], dtype=float32), array([-0.03114765], dtype=float32))
# (48, 0.00013917735, array([ 1.01337254], dtype=float32), array([-0.03039889], dtype=float32))
# (49, 0.00013256799, array([ 1.01305103], dtype=float32), array([-0.02966814], dtype=float32))
# (50, 0.00012627018, array([ 1.01273727], dtype=float32), array([-0.02895493], dtype=float32))
# (51, 0.00012027154, array([ 1.01243114], dtype=float32), array([-0.02825885], dtype=float32))
# (52, 0.00011455916, array([ 1.01213229], dtype=float32), array([-0.02757954], dtype=float32))
# (53, 0.000109118, array([ 1.01184058], dtype=float32), array([-0.02691655], dtype=float32))
# (54, 0.00010393428, array([ 1.01155603], dtype=float32), array([-0.02626948], dtype=float32))
# (55, 9.8996825e-05, array([ 1.01127815], dtype=float32), array([-0.02563799], dtype=float32))
# (56, 9.4293915e-05, array([ 1.01100707], dtype=float32), array([-0.02502165], dtype=float32))
# (57, 8.9816283e-05, array([ 1.01074243], dtype=float32), array([-0.02442015], dtype=float32))
# (58, 8.5548447e-05, array([ 1.01048422], dtype=float32), array([-0.02383308], dtype=float32))
# (59, 8.1485683e-05, array([ 1.01023221], dtype=float32), array([-0.02326016], dtype=float32))
# (60, 7.7615179e-05, array([ 1.00998616], dtype=float32), array([-0.02270102], dtype=float32))
# (61, 7.3928095e-05, array([ 1.00974619], dtype=float32), array([-0.02215528], dtype=float32))
# (62, 7.0417118e-05, array([ 1.00951183], dtype=float32), array([-0.02162271], dtype=float32))
# (63, 6.7071327e-05, array([ 1.00928319], dtype=float32), array([-0.02110289], dtype=float32))
# (64, 6.3886233e-05, array([ 1.00906003], dtype=float32), array([-0.0205956], dtype=float32))
# (65, 6.0851791e-05, array([ 1.00884223], dtype=float32), array([-0.0201005], dtype=float32))
# (66, 5.7959969e-05, array([ 1.00862968], dtype=float32), array([-0.01961729], dtype=float32))
# (67, 5.5206619e-05, array([ 1.00842226], dtype=float32), array([-0.01914569], dtype=float32))
# (68, 5.2584273e-05, array([ 1.00821984], dtype=float32), array([-0.01868545], dtype=float32))
# (69, 5.0088322e-05, array([ 1.00802207], dtype=float32), array([-0.0182363], dtype=float32))
# (70, 4.7707417e-05, array([ 1.00782931], dtype=float32), array([-0.01779787], dtype=float32))
# (71, 4.5441997e-05, array([ 1.00764108], dtype=float32), array([-0.01737002], dtype=float32))
# (72, 4.3283468e-05, array([ 1.00745738], dtype=float32), array([-0.01695245], dtype=float32))
# (73, 4.122734e-05, array([ 1.00727808], dtype=float32), array([-0.01654492], dtype=float32))
# (74, 3.9269722e-05, array([ 1.00710309], dtype=float32), array([-0.01614718], dtype=float32))
# (75, 3.7403999e-05, array([ 1.00693238], dtype=float32), array([-0.01575899], dtype=float32))
# (76, 3.5627105e-05, array([ 1.00676572], dtype=float32), array([-0.01538015], dtype=float32))
# (77, 3.3933968e-05, array([ 1.00660312], dtype=float32), array([-0.01501041], dtype=float32))
# (78, 3.2322256e-05, array([ 1.00644433], dtype=float32), array([-0.01464957], dtype=float32))
# (79, 3.0786581e-05, array([ 1.00628948], dtype=float32), array([-0.01429738], dtype=float32))
# (80, 2.9324265e-05, array([ 1.00613832], dtype=float32), array([-0.01395369], dtype=float32))
# (81, 2.7931805e-05, array([ 1.00599074], dtype=float32), array([-0.01361828], dtype=float32))
# (82, 2.6605239e-05, array([ 1.00584674], dtype=float32), array([-0.01329093], dtype=float32))
# (83, 2.5341566e-05, array([ 1.00570619], dtype=float32), array([-0.01297144], dtype=float32))
# (84, 2.4137576e-05, array([ 1.00556898], dtype=float32), array([-0.01265963], dtype=float32))
# (85, 2.2991333e-05, array([ 1.00543511], dtype=float32), array([-0.0123553], dtype=float32))
# (86, 2.1899474e-05, array([ 1.00530446], dtype=float32), array([-0.01205828], dtype=float32))
# (87, 2.0859079e-05, array([ 1.0051769], dtype=float32), array([-0.01176842], dtype=float32))
# (88, 1.9867866e-05, array([ 1.00505257], dtype=float32), array([-0.0114855], dtype=float32))
# (89, 1.8924213e-05, array([ 1.00493109], dtype=float32), array([-0.01120942], dtype=float32))
# (90, 1.8025601e-05, array([ 1.00481248], dtype=float32), array([-0.01093998], dtype=float32))
# (91, 1.7168912e-05, array([ 1.00469685], dtype=float32), array([-0.01067697], dtype=float32))
# (92, 1.6354008e-05, array([ 1.00458384], dtype=float32), array([-0.01042032], dtype=float32))
# (93, 1.5576834e-05, array([ 1.00447369], dtype=float32), array([-0.01016979], dtype=float32))
# (94, 1.4836999e-05, array([ 1.00436616], dtype=float32), array([-0.00992531], dtype=float32))
# (95, 1.4132038e-05, array([ 1.00426126], dtype=float32), array([-0.00968671], dtype=float32))
# (96, 1.3460888e-05, array([ 1.00415874], dtype=float32), array([-0.00945387], dtype=float32))
# (97, 1.2821748e-05, array([ 1.00405884], dtype=float32), array([-0.00922659], dtype=float32))
# (98, 1.2212403e-05, array([ 1.00396121], dtype=float32), array([-0.00900481], dtype=float32))
# (99, 1.1632629e-05, array([ 1.00386596], dtype=float32), array([-0.00878834], dtype=float32))
#
# === Test ===
# ('X: 5, Y:', array([ 5.01054192], dtype=float32))
# ('X: 2.5, Y:', array([ 2.50087667], dtype=float32))
